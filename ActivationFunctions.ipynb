# %% [markdown]
# <a href="https://colab.research.google.com/github/HarshaUppuluri777/fml/blob/main/ActivationFunctions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def sigmoid(x):
   return 1/(1+np.exp(-x))
x=np.linspace(-10,10)
plt.plot(x,sigmoid(x))
plt.title('Sigmoid')
plt.show()

# %%
def tanh(x):
  return (np.tanh(x))
x=np.linspace(-10,10)
plt.plot(x,tanh(x))
plt.title('tanh')
plt.show()

# %%
def relu(x):
  x1=[]
  for i in x:
    if i<0:
      x1.append(0)
    else:
      x1.append(i)
  return x1
x=np.linspace(-10,10)
plt.plot(x,relu(x))
plt.title('RELU(X)')
plt.show()

# %%
def softmax(x):
  return np.exp(x)/np.sum(np.exp(x),axis=0)
x=np.linspace(-10,10)
plt.plot(x,softmax(x))
plt.title('softmax')
plt.show()
